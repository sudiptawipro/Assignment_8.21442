# %% [markdown]
# #### Read the following data set:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',names = ['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','salary'])

# %% [markdown]
#  ### Create an sqlalchemy engine using a sample from the data set

# %%
engine = create_engine('sqlite://', echo=False)

# %%
df.to_sql("adult",  con=engine, if_exists="replace",index=False)

# %% [markdown]
# ### Write two basic update queries

# %%
sql1="""
update adult
set workclass='State_gov'
where trim(workclass)='State-gov'
"""

sql2="""
select * from 
adult where trim(workclass)='State_gov'
limit 1
"""
engine.execute(sql1)
engine.execute(sql2).fetchall()
# Out:
# [(39, 'State_gov', 77516, ' Bachelors', 13, ' Never-married', ' Adm-clerical', ' Not-in-family', ' White', ' Male', 2174, 0, 40, ' United-States', ' <=50K')]

# %%
sql3="""
update adult
set relationship='Spouse'
where trim(relationship)='Husband'
"""

sql4="""
select * from 
adult where trim(relationship)='Spouse'
limit 1
"""

engine.execute(sql3)
engine.execute(sql4).fetchall()
# Out:
# [(50, ' Self-emp-not-inc', 83311, ' Bachelors', 13, ' Married-civ-spouse', ' Exec-managerial', 'Spouse', ' White', ' Male', 0, 0, 13, ' United-States', ' <=50K')]

# %% [markdown]
# ### Write two delete queries

# %%
sql5="""
delete from adult
where trim(relationship)='Spouse'
"""

sql6="""
select * from 
adult where trim(relationship)='Spouse'
"""

engine.execute(sql5)
engine.execute(sql6).fetchall()
# Out:
# []

# %%
sql7="""
delete from adult
where age=50
"""

sql8="""
select * from 
adult 
where age=50
"""

engine.execute(sql7)
engine.execute(sql8).fetchall()
# Out:
# []

# %% [markdown]
#  ### Write two filter queries

# %%
sql9="""
SELECT  *
FROM adult 
where trim(sex)="Male"
and trim(workclass)="Private"
limit 10
"""

pd.read_sql_query(sql9, conn)
# Out:
#    age workclass  fnlwgt      education  education_num       marital_status  \
# 0   38   Private  215646        HS-grad              9             Divorced
# 1   53   Private  234721           11th              7   Married-civ-spouse
# 2   42   Private  159449      Bachelors             13   Married-civ-spouse
# 3   37   Private  280464   Some-college             10   Married-civ-spouse
# 4   32   Private  205019     Assoc-acdm             12        Never-married
# 5   40   Private  121772      Assoc-voc             11   Married-civ-spouse
# 6   34   Private  245487        7th-8th              4   Married-civ-spouse
# 7   32   Private  186824        HS-grad              9        Never-married
# 8   38   Private   28887           11th              7   Married-civ-spouse
# 9   40   Private  193524      Doctorate             16   Married-civ-spouse
#
#            occupation    relationship                 race    sex  \
# 0   Handlers-cleaners   Not-in-family                White   Male
# 1   Handlers-cleaners         Husband                Black   Male
# 2     Exec-managerial         Husband                White   Male
# 3     Exec-managerial         Husband                Black   Male
# 4               Sales   Not-in-family                Black   Male
# 5        Craft-repair         Husband   Asian-Pac-Islander   Male
# 6    Transport-moving         Husband   Amer-Indian-Eskimo   Male
# 7   Machine-op-inspct       Unmarried                White   Male
# 8               Sales         Husband                White   Male
# 9      Prof-specialty         Husband                White   Male
#
#    capital_gain  capital_loss  hours_per_week  native_country  salary
# 0             0             0              40   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2          5178             0              40   United-States    >50K
# 3             0             0              80   United-States    >50K
# 4             0             0              50   United-States   <=50K
# 5             0             0              40               ?    >50K
# 6             0             0              45          Mexico   <=50K
# 7             0             0              40   United-States   <=50K
# 8             0             0              50   United-States   <=50K
# 9             0             0              60   United-States    >50K

# %%
sql10="""
SELECT *
FROM adult 
where trim(relationship) like '%Married%'
and trim(workclass) = 'Private'
and trim(education) = 'Masters'
limit 10
"""

pd.read_sql_query(sql10, conn)
# Out:
#    age workclass  fnlwgt education  education_num          marital_status  \
# 0   44   Private  128354   Masters             14                Divorced
# 1   47   Private   87490   Masters             14                Divorced
# 2   37   Private  175232   Masters             14                Divorced
# 3   48   Private  125421   Masters             14                Divorced
# 4   43   Private   37937   Masters             14                Divorced
# 5   37   Private  262409   Masters             14                Divorced
# 6   47   Private  169092   Masters             14                Divorced
# 7   49   Private  178749   Masters             14   Married-spouse-absent
# 8   45   Private  125489   Masters             14                Divorced
# 9   46   Private  182128   Masters             14                Divorced
#
#          occupation relationship    race      sex  capital_gain  capital_loss  \
# 0   Exec-managerial    Unmarried   White   Female             0             0
# 1   Exec-managerial    Unmarried   White     Male             0             0
# 2   Exec-managerial    Unmarried   White     Male             0             0
# 3   Exec-managerial    Unmarried   White   Female             0             0
# 4   Exec-managerial    Unmarried   White     Male             0             0
# 5   Exec-managerial    Unmarried   White   Female             0           213
# 6    Prof-specialty    Unmarried   White   Female             0             0
# 7      Adm-clerical    Unmarried   White   Female             0             0
# 8    Prof-specialty    Unmarried   White   Female             0             0
# 9    Prof-specialty    Unmarried   White   Female          6497             0
#
#    hours_per_week  native_country  salary
# 0              40   United-States   <=50K
# 1              42   United-States   <=50K
# 2              60   United-States    >50K
# 3              40   United-States    >50K
# 4              50   United-States   <=50K
# 5              45   United-States   <=50K
# 6              50   United-States    >50K
# 7              40   United-States   <=50K
# 8              50   United-States   <=50K
# 9              50   United-States   <=50K

# %% [markdown]
# ###  Write two function queries

# %%
sql11="""
SELECT workclass,max(age) as MAX_Age,min(age) as MIN_Age,avg(age) as AVG_Age
FROM adult 
group by(workclass)
"""

pd.read_sql_query(sql11, conn)
# Out:
#            workclass  MAX_Age  MIN_Age    AVG_Age
# 0                  ?       90       17  40.960240
# 1        Federal-gov       90       17  42.590625
# 2          Local-gov       90       17  41.751075
# 3       Never-worked       30       17  20.571429
# 4            Private       90       17  36.797585
# 5       Self-emp-inc       84       17  46.017025
# 6   Self-emp-not-inc       90       17  44.969697
# 7        Without-pay       72       19  47.785714
# 8          State_gov       81       17  39.436055

# %%
sql12="""
SELECT occupation,max(age) as MAX_Age,min(age) as MIN_Age,avg(age) as AVG_Age
FROM adult 
group by(occupation)
"""

pd.read_sql_query(sql12, conn)
# Out:
#             occupation  MAX_Age  MIN_Age    AVG_Age
# 0                    ?       90       17  40.882800
# 1         Adm-clerical       90       17  36.964456
# 2         Armed-Forces       46       23  30.222222
# 3         Craft-repair       90       17  39.031471
# 4      Exec-managerial       90       17  42.169208
# 5      Farming-fishing       90       17  41.211268
# 6    Handlers-cleaners       90       17  32.165693
# 7    Machine-op-inspct       90       17  37.715285
# 8        Other-service       90       17  34.949621
# 9      Priv-house-serv       81       17  41.724832
# 10      Prof-specialty       90       17  40.517633
# 11     Protective-serv       90       17  38.953775
# 12               Sales       90       17  37.353973
# 13        Tech-support       73       17  37.022629
# 14    Transport-moving       90       17  40.197871
